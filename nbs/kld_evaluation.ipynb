# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('klds.csv')
df

afs = df['aux_factor'].values
klds = df['kld'].values

plt.figure(figsize=(16, 9))
plt.plot(afs[:-1], klds[:-1], 'o--', label='auxiliary')
plt.axhline(klds[-1], color='red', linestyle='--', label='conditional')
plt.legend()
plt.xscale('log',base=2) 
plt.xticks(afs[:-1])
plt.xlabel('auxiliary weighting factor')
plt.ylabel('KLD')
plt.show()

# %%
df = pd.read_csv('klds_100.csv')
df

afs = df['aux_factor'].values
klds = df['kld'].values

plt.figure(figsize=(16, 9))
plt.plot(afs[:-1], klds[:-1], 'o--', label='auxiliary')
plt.axhline(klds[-1], color='red', linestyle='--', label='conditional')
plt.legend()
plt.xscale('log',base=2) 
plt.xticks(afs[:-1])
plt.xlabel('auxiliary weighting factor')
plt.ylabel('KLD')
plt.show()

# %%
df = pd.read_csv('klds_500.csv')
df

afs = df['aux_factor'].values
klds = df['kld'].values

plt.figure(figsize=(16, 9))
plt.plot(afs[:-1], klds[:-1], 'o--', label='auxiliary')
plt.axhline(klds[-1], color='red', linestyle='--', label='conditional')
plt.legend()
plt.xscale('log',base=2) 
plt.xticks(afs[:-1])
plt.xlabel('auxiliary weighting factor')
plt.ylabel('KLD')
plt.show()

# %%
df = pd.read_csv('klds_1000.csv')
df

afs = df['aux_factor'].values
klds = df['kld'].values

plt.figure(figsize=(16, 9))
plt.plot(afs[:-1], klds[:-1], 'o--', label='auxiliary')
plt.axhline(klds[-1], color='red', linestyle='--', label='conditional')
plt.legend()
plt.xscale('log',base=2)
plt.xticks(afs[:-1])
plt.xlabel('auxiliary weighting factor')
plt.ylabel('KLD')
plt.show()
